# %% [markdown]
# # COGS 108 - Covid-19 in the U.S. and Stock Prices of Automotive Companies

# %% [markdown]
# ## Project Video
# https://drive.google.com/file/d/1wGKQlGfzXsSOhnI2A8lBE1bLzR0vORs8/view?usp=sharing

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [ X ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# Since the birth of the automobile, the automobile industry and the stocks that represent it have been the pillars of many countries and cities and one of the benchmarks of the financial market industry. As stock prices have a huge impact on the auto industry and represent the market's view of the auto industry, with the Covid-19 outbreak, we assume that the outbreak will lead to a different perception of the auto industry and will respond quickly in the auto industry above the stock price. Since the U.S. stock market includes most auto companies from different countries to a certain extent, we assume that the auto research in the U.S. stock market can generalize the auto stocks of different countries. The purpose of this study will be Is there a relationship between the severity of the COVID-19 pandemic in the United States and the stock price of internationally major automotive companies? Due to the reduced travel, remote work and other policies brought about by the outbreak, we believe this will affect and reduce the share price of individual stocks, so we wanted to see if there is a strong positive correlation with stock price per share of automotive companies. Severity of COVID-19 will take into account of daily increase of death, hospitalization, positve cases and total test cases in our research.
# After preliminary reading the work of our peers, we preliminarily determined that this relationship exists, but it is not simply positive or negative correlation. Therefore, we created a database of eleven auto stock prices, and performed basic data cleaning on the database. After some data analysis and visualization, we initially determined that this relationship exists, but there is a variable of people's familiarity with the epidemic and the degree of panic that affects this relationship.In the early days of the epidemic, the severity of the epidemic was proportional to the decline in stock prices due to panic about the epidemic. However, people gradually understand the epidemic, the liberalization of policies and the rebound of ideas have led to an increase in people's demand for cars despite the severity of the epidemic, which has led to an increase in stock prices, that is, the severity of the epidemic is inversely proportional to the decline in stock prices, which is consistent with our previous understanding of the prior works. In the end by further analysis, that is, visualizing the correlation, we ensure the accuracy of the conclusions. So our final conclusion is that there is a relationship between the severity of COVID-19 pandemic in the United States and the stock price of internationally major automotive companies, and there is a strong positive correlation with stock price per share of automotive companies in the early breakout time with a high level of panic to the covid, but it turns into a strong negative correlation with stock price per share of automotive companies in the late breakout time with a low level of panic to the covid.

# %% [markdown]
# # Names
#
# - Chenyu Zhang A16526395
# - Zhengxi Zhang A17220038
# - Mengyuan Zhang A15598814
# - Harry Lei A15890785
# - Hongchang Jiang A17180573

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Is there a relationship between the severity of COVID-19 pandemic in the United States and the stock price of internationlly major automotive companies? If there is, does severity of COVID-19 have a strong positive correlation with stock price per share of automotive companies? Severity of COVID-19 will take into account of daily increase of death, hospitalization, positve cases and total test cases.

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# ## Introduction:
# As a major automobile producer, the economic development of many regions in the United States largely depends on the automobile industry. For example, in Detroit, auto workers once became synonymous with the city, and car production depends to some extent on sales volume. Only with sufficient sales volume can economic activities such as car production continue without causing layoffs. As an automobile company, it is essential to analyze the possible sales volume in the future to adopt the production work policy for the next quarter. But with the outbreak of the 2020 Covid epidemic in the United States, social distancing and remote work policies may greatly affect people's going out and the demand for cars. On the other hand, for many people who took public transportation before the epidemic, the fear of infection due to social distancing has also increased their demand for cars. This makes the analysis of the data with great uncertainty. So in our study, we tried to understand whether there was a close relationship between the severity of the outbreak (the daily coronavirus cases in the US) and stock price per share of automotive companies. <br>
#
# ## Prior Work:
# We chose a few similar works conducted related to the relationship between the car market and Covid-19’s impact. One study indicated that due to avoiding mass transportation, Covid-19 has led to an increase in used car sales.According to his point of view, car sales in the early stage of the epidemic have dropped significantly, but with the re-influence of Delta and omicron, people's demand for private transportation travel will rise again. It is expected that the sales volume that has dropped sharply in the early stage of the epidemic due to remote working, keeping social distance and other policies will pick up again, that is, the decrease in the number of infected people may lead to an increase in car sales. In another study focused on the saling cases of auto industries during pandemic, the researchers compared the data of the car manufacturers before and after the pandemic and drew the conclusion that the car manufacturers faced disruption in business areas and had trouble with remote saling patterns during the pandemic.
# <br>
# <br>
# According to the prior works we found, we noticed that a larger number of researchers concluded that the pandemic has a positive relationship with the decrease of car sales compared to the opposite opinion.  Thus, we decided that though there are many elements affecting the number of car sales, we can hypothesize that there is a relationship between the increase of coronavirus disease cases and the decrease of stock price per share of automotive companies.
#
# <br>
# reference: <br>
# 1.[The used car boom is one of the hottest, and trickiest, coronavirus markets for consumers](https://www.cnbc.com/2020/10/15/used-car-boom-is-one-of-hottest-coronavirus-markets-for-consumers.html)
#
# 2.[The case of sales in the automotive industry during theCOVID-19 pandemic](https://onlinelibrary.wiley.com/share/JR7NBGPACG4NCCMFWEI8?target=10.1002/jsc.2395)

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Based on our background and prior work, our hypothesis is that there is a relationship between the increase of coronavirus disease cases and the decrease of stock price per share of automotive companies.
# <br>
# We made this hypothesis based on our understanding of the background of our topic: families may not be able to afford cars because of the decrease of income caused by the pandemic, and the demand for using cars is also decreased during remote working and studying. The research and data we found in the related works also support our hypothesis.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - **U.S National COVID-19 Daily Data**
#    - Dataset Name: national-history.csv
#    - Link to the dataset: https://covidtracking.com/data/download/national-history.csv
#    - Number of observations: 420 observations
#    - This dataset contain summary of daily data on the COVID-19 pandemic for the United States. It provides information on varaibles such as daily increase of death, positive cases, negative cases, hospitalization and total number of tests. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for Internationlly Major Automotive Companies(Mutiple Dataset combined by 11 Individual Datasets)**
#    - Dataset Name: bmw.csv,ford.csv,gm.csv,honda.csv,nissan.csv,toyota.csv, Volkswagen.csv
#    - Link to the dataset: https://finance.yahoo.com/quote/BMW.DE/history?p=BMW.DE,
#                           https://finance.yahoo.com/quote/GM/history?p=GM,
#                           https://finance.yahoo.com/quote/Ford/history?p=GM,
#                           https://finance.yahoo.com/quote/HMC/key-statistics?p=HMC,
#                           https://finance.yahoo.com/quote/NSANY/history?p=NSANY,
#                           https://finance.yahoo.com/quote/RYCEY/history?p=RYCEY,
#                           https://finance.yahoo.com/quote/TTM/history?p=TTM,
#                           https://finance.yahoo.com/quote/TM/history?p=TM,
#                           https://finance.yahoo.com/quote/VWAGY/history?p=VWAGY
#    - Number of observations: 13312 observations
#    - This dataset contain summary of daily data on stock prices of all internationlly major automotive companies we have collected which is totally 11 dataset. It contains the variables like date, open price, high price, low price, close price, etc. The way we made this dataset is by adding a new column Maker to indicate the company for each observation, and each observation is based on the date oberserved in each individual dataset, then we performing a full join with the same column type all dataset shared since they are all come from the same source website yahoo finance.And because of that, we have the total ovservations sum of all other 11 datasets.
#
# <br>
#
# -  **Stock Price for BMW**
#     - Dataset Name: bmw.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/BMW.DE/history?p=BMW.DE
#     - Number of observations: 1267 observations
#     - This dataset contain summary of daily data on stock prices of BMW. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for General Motos**
#     - Dataset Name: gm.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/GM/history?p=GM
#     - Number of observations: 1259 observations
#     - This dataset contain summary of daily data on stock prices of General Motors. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for Ford**
#     - Dataset Name: gm.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/Ford/history?p=GM
#     - Number of observations: 1259 observations
#     - This dataset contain summary of daily data on stock prices of Ford. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for Honda**
#     - Dataset Name: honda.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/HMC/key-statistics?p=HMC
#     - Number of observations: 1259 observations
#     - This dataset contain summary of daily data on stock prices of Honda. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for Nissan**
#     - Dataset Name: nissan.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/NSANY/history?p=NSANY
#     - Number of observations: 1242 observations
#     - This dataset contain summary of daily data on stock prices of Nissan. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for Toyota**
#     - Dataset Name: toyota.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/TM/history?p=TM
#     - Number of observations: 1259 observations
#     - This dataset contain summary of daily data on stock prices of Toyota. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# - **Stock Price for Volkswagen**
#     - Dataset Name: Volkswagen.csv
#     - Link to the dataset: https://finance.yahoo.com/quote/VWAGY/history?p=VWAGY
#     - Number of observations: 1267 observations
#     - This dataset contain summary of daily data on stock prices of Volkswagen. It contains variables like open price, high price, low price, close price, etc. The observation for this dataset is based on the date oberserved.
#
# <br>
#
# **How to combine these datasets**: Since all datasets regarding the stock prices are from Yahoo finance, the structure for each dataframe is quite similar. Due to each stock dataframe shares a common variable, date, which represent the observation in our individual stock dataframe, thus we can just combine these datasets based on the date of individual observations. Then, consider making a new column called maker to mark the company which the observations come from, a simple concatenation would merge indivudla stock datasets into one large dataframe.

# %% [markdown]
# # Setup

# %%
# Importing necessage pacakges
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support
import patsy
import statsmodels.api as sm

# %% [markdown]
# # Data Cleaning
# ### General Steps:
# 1. Concatenate dataframes of each individual automotive company into one large dataframe called **car**
# 2. Standardize data sets
# 3. Add extra variable called 'Maker' to **car** dataframe to facilitate further EDA analysis
# 4. Drop any duplicate observations that have the same date in both **car** and **covid** dataframe
# 5. Drop any columns that only has NaN values in both **car** and **covid** dataframe
# 6. Filter **covid** dataframe to only include observations that has non-zero Covid cases
# 7. Reduce **covid** dataframe to five variables: date, deathIncrease, hospitalizedIncrease, positiveIncrease and totalTestResultsIncrease
# 8. Filter **car** dataframe to match the time scope of **covid** dataframe
# 9. Rename columns of **car** dataframe to make naming conventions consistent
# 10. Sort **car** dataframe in descending orders to make date consistent with **covid** dataframe

# %% [markdown]
# ### Table of Contents:
# - Stock Price Data
#   - BMW
#   - Ford
#   - General Motors
#   - Honda
#   - Nissan
#   - Toyota
#   - Volkswagen
# - Covid-19 Data

# %% [markdown]
# ### Stock Price Data:

# %% [markdown]
# #### I.
# First we load & clean data from the folder called 'Car', which contains csv files for each individual automotive company from 2020 to 2021. The data itself is generally clean, but we do need to mange to merge each dataframe into a large dataframe. To achieve that, we create a new variable called 'Maker', which specifies which company the observation belongs to. After the new variable is created for each observation, we concatenate each dataframe to a new dataframe by rows, thus the new dataframe contains all observations from each individual datasets.

# %%
# Read Data from Car folder
data_dir = 'Car'
folder_name = ['BMW','Ford','General Motors','Honda','Nissan','Toyota','Volkswagen']

file_name = []
for name in folder_name:
    if (name == 'Volkswagen'):
        tmp = name
    elif name == 'General Motors':
        tmp = 'gm'
    else:
        tmp = name.lower()
    file_name.append(tmp)

df_name = []

for i,fname in enumerate(file_name):
    file_path = os.path.join(data_dir,folder_name[i])
    file_path = os.path.join(file_path,fname) + '.csv'
    if " " in fname:
        fname = fname.replace(" ","")
    globals()[fname] = pd.read_csv(file_path)
    globals()[fname]['Maker'] = fname
    df_name.append(fname)

df_list = [bmw, ford, gm, honda, nissan, toyota, Volkswagen]
car = pd.DataFrame()

#standardize data sets
for i in df_list:
    i['diff'] = i['Adj Close'] - i['Open']
    for j in ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']:
        i[j] = (i[j]-i[j].mean())/i[j].std()
    
for df in df_list:
    df = df.drop_duplicates(subset=['Date'])
    car = pd.concat([car, df], axis='rows')


car.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume  \
# 0  2020-01-07  1.234106  1.224573  1.280081  1.287863   0.909407 -0.681405
# 1  2020-01-08  1.271624  1.244618  1.324527  1.308632   0.928138 -1.037220
# 2  2020-01-09  1.399625  1.339270  1.390653  1.303166   0.923208 -0.593510
# 3  2020-01-10  1.332314  1.295841  1.375477  1.326121   0.943908 -0.878892
# 4  2020-01-13  1.355486  1.279138  1.285501  1.223369   0.851247 -1.094160
#
#   Maker      diff
# 0   bmw -6.496475
# 1   bmw -6.664688
# 2   bmw -7.869895
# 3   bmw -7.070038
# 4   bmw -8.129906

# %% [markdown]
# #### II.
# For the data cleaning part, we first filtered out any duplicate observations, which are observations that share the same date, during the process of concatenation. In addition, we filtered out any columns that only have NaN values. Furthermore, given that the dataframe gathers data from 2020 to 2021, there are many observations that dates before the outbreak of Covid-19, thus we filtered out such observations to minimize any outliers that could interfere with our further analysis. Also, we renamed columns of the dataframe to make sure that the naming convention for variables can maintain consistent accross all datasets. Lastly, we sorted the dataframe by date in descending order to make date consistnt accross all datasets.

# %%
#clean car dataframe
car = car.dropna(how='all')
car = car[ car['Date'] > '2020-01-16' ]
car = car[ car['Date'] < '2021-03-09' ]
car = car.rename(columns={'Date':'date','Open':'open','High':'high','Low':'low','Close':'close','Adj Close':'adjClose','Volumn':'volumn','Maker':'maker'})
car = car.sort_values(by='date', ascending=False)

car.head()
# Out:
#             date      open      high       low     close  adjClose    Volume  \
# 1148  2021-03-08  1.663357  1.587103  1.507916  1.593259  1.735445  1.058356
# 1140  2021-03-08  1.900063  2.060287  1.917617  1.988225  2.118597  1.483511
# 296   2021-03-08  1.558523  1.840371  1.625888  1.880324  1.883937  0.281088
# 1140  2021-03-08  1.146738  1.217611  1.158008  1.126023  1.126454  2.294829
# 1140  2021-03-08  0.189888  0.284076  0.230485  0.231781  0.231781  1.623531
#
#            maker      diff
# 1148  Volkswagen -6.796006
# 1140          gm  0.689999
# 296          bmw -0.498268
# 1140      toyota -0.340011
# 1140       honda  0.119999

# %% [markdown]
# ### Covid-19 Data

# %% [markdown]
# #### I.
# First we load data from the csv dataset containing national daily data on the COVID-19 pandemic of the U.S. The Data does not need to be cleaned much, given that the format for each variale is consistent. But there are many variables that have missing data. And there are many variables such as the states and onVentilatorCurrently that we will not look into for our research, which need to be cleaned to facilate our further analysis.

# %%
#Read covid data from online sources
covid = pd.read_csv('https://covidtracking.com/data/download/national-history.csv')
covid.head()
# Out:
#          date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0  2021-03-07  515151.0            842          45475.0          8134.0
# 1  2021-03-06  514309.0           1680          45453.0          8409.0
# 2  2021-03-05  512629.0           2221          45373.0          8634.0
# 3  2021-03-04  510408.0           1743          45293.0          8970.0
# 4  2021-03-03  508665.0           2449          45214.0          9359.0
#
#    hospitalizedIncrease  hospitalizedCurrently  hospitalizedCumulative  \
# 0                   726                40199.0                776361.0
# 1                   503                41401.0                775635.0
# 2                  2781                42541.0                775132.0
# 3                  1530                44172.0                772351.0
# 4                  2172                45462.0                770821.0
#
#      negative  negativeIncrease  onVentilatorCumulative  \
# ...

# %% [markdown]
# #### II.
# For the data cleaning part, we first filtered out any duplicate observations, which are observations that share the same date. In addition, we filtered out any columns that only have NaN values. Furthermore, we filtered out some observations that dates before the outbreak of Covid-19 to minimize outliers. Lastly, since we are focusing on daily increase of death, hospitalization, positve and test results, we filtered out any other variables that are extranuous to our analysis

# %%
#clean covid dataframe
covid = covid.drop_duplicates(subset=['date'])
covid = covid.dropna(how='all')
covid = covid[covid['positiveIncrease'] != 0.0]
covid = covid[['date', 'deathIncrease', 'hospitalizedIncrease', 'positiveIncrease', 'totalTestResultsIncrease']]

#standardize data sets
for j in ['deathIncrease', 'hospitalizedIncrease', 'positiveIncrease', 'totalTestResultsIncrease']:
        covid[j] = (covid[j]-covid[j].mean())/covid[j].std()
        
covid.head()
# Out:
#          date  deathIncrease  hospitalizedIncrease  positiveIncrease  \
# 0  2021-03-07      -0.472976             -0.765093         -0.480239
# 1  2021-03-06       0.326037             -0.897300         -0.214521
# 2  2021-03-05       0.841868              0.453225         -0.086310
# 3  2021-03-04       0.386106             -0.288437         -0.134542
# 4  2021-03-03       1.059260              0.092176         -0.114825
#
#    totalTestResultsIncrease
# 0                  0.356860
# 1                  0.770604
# 2                  1.267580
# 3                  1.024292
# 4                  0.732236

# %%
covid = covid.sort_values(by='date', ascending=True)
car = car.sort_values(by='date', ascending=True)
car = car.reset_index()
car = car.drop(['index'],axis = 1)

# Audi AG has been discountinued, remove from dataframe
car = car[ car['maker'] != 'audi' ]
car = car[ car['maker'] != 'NIO' ]
car = car[ car['maker'] != 'rollsroyces' ]
car = car[ car['maker'] != 'tata' ]

car.head()
# Out:
#          date      open      high       low     close  adjClose    Volume  \
# 0  2020-01-17  1.023347  0.960660  1.016661  0.942442  0.597908  0.119182
# 1  2020-01-17  0.601565  0.586984  0.632275  0.624465  0.625632 -1.043669
# 2  2020-01-17  1.032462  1.034940  1.105736  1.048338  1.013701 -0.475912
# 3  2020-01-17 -0.315506 -0.346484 -0.279123 -0.308886 -0.121903 -0.500143
# 4  2020-01-17 -0.331298 -0.368726 -0.302040 -0.320879 -0.320879 -0.974003
#
#         maker       diff
# 0         bmw  -7.443496
# 1      toyota   0.360000
# 2  Volkswagen -10.366912
# 3          gm  -0.399052
# 4       honda   0.020001

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# ### General Steps:
# 1. Check dataset(**covid** and **car**)'s variable and observation
# 2. Merge **covid** and **car** into a new dataset called **merge**
# 3. Oberservate the **merge** by checking its variable, oberservation and missingness. Analysis and explain the missingness.
# 4. Check **covid** and **car**'s descriptive statistics of Dataframes. such as mean, count, std,etc
# 5. Visualizing by creating a lineplot based on the dateset **covid**(X as the date record in **covid**, y as the number record in **covid** with three line represent the variables - **Death**, **Hospitalized** and **Positive**)
# 6. Visualizing by creating another lineplot based on the dateset **car**(X as the date record in **car**, y as the Adjusted Close price record in **car** with three line represent the variables of 7 car brands- **Death**, **Hospitalized** and **Positive**)
# 7. Create a correlation table with 4 variables - **positiveIncrease**, **hospitalizedIncrease**, **deathIncrease** and **totalTestResultsIncrease** to check their responding correlation. Explain the number showing in the correaltion table.
# 8. Based on our data tables, lineplots and correlation table, make a conclusion.
#
# ### Checking the size of dataframes
#
# First we begin with checking the datasets car and covid's observations and variables. By observation we have seen that they hava a same variable date, so we decide to merge them using the variable date into a new dataset called merge. Then, observate merge and the descriptive statistics of other dataframes help us better understand what we are missing in the first two datasets which is there are no trading hours for stocks on Saturdays and Sundays, the car dataframe does not contain weekend observations. Also, since our covid dataframe starts from 2020-01-19, it does not contain any observations before this date.

# %%
#Check Dataset Car's observations and column variables
car.shape
# Out:
# (2008, 9)

# %%
#Check Dataset covid's observations and column variables
covid.shape
# Out:
# (385, 5)

# %% [markdown]
# ### Merging and Checking for Missingness

# %%
#Merge two datasets car, covid into one new dataset called merge by their similar column variable: date 
merge = pd.merge(car, covid, how='outer', on = 'date')
merge.head()
# Out:
#          date      open      high       low     close  adjClose    Volume  \
# 0  2020-01-17  1.023347  0.960660  1.016661  0.942442  0.597908  0.119182
# 1  2020-01-17  0.601565  0.586984  0.632275  0.624465  0.625632 -1.043669
# 2  2020-01-17  1.032462  1.034940  1.105736  1.048338  1.013701 -0.475912
# 3  2020-01-17 -0.315506 -0.346484 -0.279123 -0.308886 -0.121903 -0.500143
# 4  2020-01-17 -0.331298 -0.368726 -0.302040 -0.320879 -0.320879 -0.974003
#
#         maker       diff  deathIncrease  hospitalizedIncrease  \
# 0         bmw  -7.443496            NaN                   NaN
# 1      toyota   0.360000            NaN                   NaN
# 2  Volkswagen -10.366912            NaN                   NaN
# 3          gm  -0.399052            NaN                   NaN
# 4       honda   0.020001            NaN                   NaN
#
#    positiveIncrease  totalTestResultsIncrease
# 0               NaN                       NaN
# 1               NaN                       NaN
# ...

# %%
#Check the bottom data of Dataset merge's observations and column variables
merge.tail()
# Out:
#             date  open  high  low  close  adjClose  Volume maker  diff  \
# 2116  2021-02-21   NaN   NaN  NaN    NaN       NaN     NaN   NaN   NaN
# 2117  2021-02-27   NaN   NaN  NaN    NaN       NaN     NaN   NaN   NaN
# 2118  2021-02-28   NaN   NaN  NaN    NaN       NaN     NaN   NaN   NaN
# 2119  2021-03-06   NaN   NaN  NaN    NaN       NaN     NaN   NaN   NaN
# 2120  2021-03-07   NaN   NaN  NaN    NaN       NaN     NaN   NaN   NaN
#
#       deathIncrease  hospitalizedIncrease  positiveIncrease  \
# 2116      -0.048679             -0.604429         -0.233712
# 2117       0.485268             -0.348909         -0.050384
# 2118      -0.273700             -0.674386         -0.297335
# 2119       0.326037             -0.897300         -0.214521
# 2120      -0.472976             -0.765093         -0.480239
#
#       totalTestResultsIncrease
# 2116                  0.456653
# 2117                  1.126081
# 2118                  0.734816
# 2119                  0.770604
# ...

# %% [markdown]
# ### Descriptive Statistics of Dataframes

# %%
#Check Dataset covid's mean, count, std,etc.
covid = covid[['date','positiveIncrease', 'deathIncrease', 'totalTestResultsIncrease']]
covid.describe()
# Out:
#        positiveIncrease  deathIncrease  totalTestResultsIncrease
# count      3.850000e+02   3.850000e+02                385.000000
# mean       1.107339e-16   7.382262e-17                  0.000000
# std        1.000000e+00   1.000000e+00                  1.000000
# min       -1.091682e+00  -1.275804e+00                 -1.498422
# 25%       -7.000477e-01  -6.836947e-01                 -0.838921
# 50%       -3.757200e-01  -2.479559e-01                 -0.086535
# 75%        4.575348e-01   4.290124e-01                  0.805776
# max        3.221775e+00   3.898713e+00                  2.164202

# %%
#Check Dataset car's mean, count, std,etc.
car.describe()
# Out:
#               open         high          low        close     adjClose  \
# count  2008.000000  2008.000000  2008.000000  2008.000000  2008.000000
# mean     -0.242477    -0.232748    -0.253886    -0.244109    -0.178543
# std       0.986924     0.982139     0.994869     0.989363     0.967426
# min      -2.859050    -2.872222    -2.997139    -2.895627    -2.895627
# 25%      -0.903756    -0.885140    -0.919555    -0.894889    -0.811210
# 50%      -0.346395    -0.357553    -0.357731    -0.351893    -0.295440
# 75%       0.385629     0.384898     0.389127     0.381207     0.451408
# max       2.546390     2.580263     2.477918     2.554582     2.559910
#
#             Volume         diff
# count  2008.000000  2008.000000
# mean      0.203955    -1.497557
# std       1.136799     2.976362
# min      -1.634050   -19.031296
# 25%      -0.558761    -2.099862
# 50%      -0.093356    -0.170000
# 75%       0.624242     0.060001
# max      10.488689     5.559998

# %% [markdown]
# ### Visualization

# %% [markdown]
# For Visualization, we are going to use the dataset car and covid. By representing the main variables in covid - deathIncrease and positiveIncrease as y and the date as x we have a lineplot with 3 lines showing the severity, peak, scope of outbreak. Then we use the main variables from car - toyota, ford, gm, bmw, nissan, honda, and Volkswagen to make another lineplot with 7 lines showing the peak, scope of the stock price. In the end, by making a table with  deathIncrease, positiveIncrease and totalTestResultsIncrease to check their responding correlation to each other, we find daily positive increase is positively correlated with daily hospitalized and daily death, so we can use only the daily positive increase to explore the correlation between stock price and Covid-19.

# %%
#Create plot to show the change of number in Death and Positive Increase in date
f1 = plt.gcf()
f1.set_size_inches(10,5)
x = covid['date']

plt.plot(x, covid['deathIncrease'], label='Death')
plt.plot(x, covid['positiveIncrease'], label='Positive')
plt.xlabel('Date')
plt.ylabel('Number')
plt.legend(loc = 'upper right')
plt.xticks(np.arange(0,365,50))
plt.show()

# %%
#Create plot to show the change of number in stock price of every car brandin date
fig, ax = plt.subplots()
ax = sns.lineplot(x = 'date', y ='adjClose', hue = 'maker', data = car)
ax.set(xlabel = 'Date', ylabel= 'Adjusted Close price')
ax.set_xticks(range(0, 300, 45))
fig.set_size_inches(10, 5)

# %%
#sns.regplot(data = merge, x = 'deathIncrease', y = 'deathIncrease',line_kws={"color": "red"})
covid_corr = covid.corr()
covid_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e1841_row0_col0, #T_e1841_row1_col1, #T_e1841_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e1841_row0_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e1841_row0_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_e1841_row1_col0, #T_e1841_row1_col2, #T_e1841_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e1841_row2_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# </style>
# <table id="T_e1841">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1841_level0_col0" class="col_heading level0 col0" >positiveIncrease</th>
#       <th id="T_e1841_level0_col1" class="col_heading level0 col1" >deathIncrease</th>
#       <th id="T_e1841_level0_col2" class="col_heading level0 col2" >totalTestResultsIncrease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Daily positive increase is positively correlated with daily hospitalized and daily death, therefore we use only the daily positive increase to explore the correlation between severity of Covid-19 and stock price of automotive companies.

# %%
fig, ([ax1, ax2], [ax3, ax4], [ax5, ax6], [ax7, ax8]) = plt.subplots(ncols = 2, nrows = 4, sharey = True, figsize=(20,30))
sns.set(font_scale=1, style="white")

sns.regplot(data = merge[merge['maker']=='bmw'], ax=ax1, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['maker']=='gm'], ax=ax2, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['maker']=='ford'], ax=ax3, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['maker']=='Volkswagen'], ax=ax4, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['maker']=='nissan'], ax=ax5, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['maker']=='honda'], ax=ax6, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['maker']=='toyota'], ax=ax7, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})

plt.suptitle('Correlation between Daily Increase with Adjusted Close Price', fontsize=20)
fig.subplots_adjust(top=0.95)
ax1.title.set_text('bmw')
ax2.title.set_text('gm')
ax3.title.set_text('ford')
ax4.title.set_text('Volkswagen')
ax5.title.set_text('nissan')
ax6.title.set_text('honda')
ax7.title.set_text('toyota')

# %% [markdown]
# From the reg plot alone, we can find some vague relationships between daily increase of Covid-19 and adjusted close stock prices of automotive companies. However, such analysis does not have a strong foundation to back up our research question, thus further analysis including regression and scatter matrix should be performed to make the final conclusion.

# %% [markdown]
# ### EDA Conclusion

# %% [markdown]
# With visualization, we can find four inflection points in the graph obtained in the Covid database. In the following analysis, we will use the four inflection points and the stationary period after the inflection point to analyze by date. At the end, we will analyze their correlation to provide support for our research question.
#
# #### The First outbreak of the epidemic(Jan,2020 to June,2020)
#
# During this period, the epidemic began to spread across North America from zero, and the number of daily infections increased from January to March until it gradually reached 30,000 to 40,000 per day, and maintained this number until June. As can be seen from our plot of auto stock prices, auto stock prices fell rapidly from January until March began to rebound to a certain extent, but they could not return to the prices before the epidemic, and with the second outbreak of the epidemic in June, the Shares fell again. This is obviously in line with our conjecture that the severity of the epidemic will make people feel uneasy about auto stocks, which will affect the stock price and cause the stock price to drop. severity of COVID-19 have a strong positive correlation with stock price per share of automotive companies
#
# #### The Second outbreak of the epidemic(June,2020 to Sep,2020)
#
# During this period, the second outbreak of the epidemic occurred, from about 30,000 daily infections before June until the peak in July and then slowly declining until September, but always above 50,000.
# As can be seen from our plot of auto stock prices, the rebound period of auto stock prices that started in March ended in June, and the stock prices began to decline rapidly until the peak of the epidemic in July, and with the reduction in the number of daily epidemic infections, the stock prices began to fall again. of rebound. This is also in line with our conjecture that as the severity of the outbreak subsides, there is renewed confidence in auto stock prices. We can still argue that the severity of COVID-19 has a strong positive correlation with stock price per share of automotive companies
#
# #### The Third outbreak of the epidemic(Sep,2020 to Jan,2021)
#
# During this period, the third outbreak of the epidemic occurred. From September to October, the number of daily infections began to rebound slowly, and then ushered in a sharp and exaggerated rise from September to January. The number of infections rose from about 50,000 in September to about 70,000 in October, and spiked to around 150,000-200,000 per day for the next four months.
# As you can see from our plot of auto share prices, auto share prices differ from our previous understanding that severity of COVID-19 have a strong positive correlation with stock price per share of automotive companies. The doubling of the number of people infected by the epidemic has not caused the stock price to fall again, but has caused the stock price to soar rapidly. From October to November when the epidemic grew rapidly, in just over a month, most of the auto stock prices rose by at least 30%, and after that, it continued to grow as the number of people affected by the epidemic increased. It can be seen that during this period, the severity of the epidemic has always had an impact on auto stock prices, But this time severity of COVID-19 have a strong negative correlation with stock price per share of automotive companies
#
# #### The Ending outbreak of the epidemic(Jan,2021 to Feb,2021)
#
# During this period, the impact of the third outbreak of the epidemic began to gradually end. The number of daily infections has dropped to 50000 from a range of 150,000 - 200,000 in previous months.
# Unlike the previous few times, the sharp reduction in the number of infected people did not significantly affect the stock price, and the stock price of most auto stocks did not increase or decrease significantly, which made this short period of time an outlier in us. in the analysis. Due to the lack of observation samples and the follow-up situation, we believe that this period of time showing that the severity of the epidemic does not have much relationship with the stock price of automobiles has no significance to affect the conclusion, and can be treated as an outlier.
#
# #### EDA Conclusion
# In the above analysis, we found that the severity of COVID-19 has a strong correlation with stock price per share of automotive companies through the analysis of the data and the chart, and before the third outbreak, that is, before September 2020 , this relationship is strongly positive. But we have a reasonable doubt that as people adapt to the epidemic, the impact of the increase in the number of infections, such as policy changes, the demand for cars has led people to be optimistic about auto stocks again, which has led to stock prices skyrocketing. After the third major outbreak, the increase in daily infections caused by the outbreak led to a major increase in auto stocks. Our initial conclusion is that there is a relationship between the severity of the COVID-19 pandemic in the United States and the stock price of internationlly major automotive companies, but as people adjust to the outbreak, it changes from a strong positive to a strong negative relationship.

# %% [markdown]
# ### Further Analysis

# %% [markdown]
# After considering our initial EDA conclusions, we believe that our conclusions always lack real data analysis, so we will make data analysis in this section to ensure that there is a clear correlation between auto stock prices and the severity of the Covid.Compared with the previous stage that we mainly used the increase in the number of infected people. In this stage, we will analyze the correlation between the increase in the number of infected people and auto stock prices as a whole, which will help us better understand the severity of the outbreak and ensure that the conclusion we extracted can be generalzied.

# %% [markdown]
# In the EDA process, we dissect the time scope(2020-01-17 to 2021-03-07) into four outbreak phases. Given the correlation that we are exploring: the correlation between daily inrease of Covid-19 cases and stock prices of automotive companies, may vary from period to period. We decide to create a new variable that keeps track of each outbreak period.

# %%
def outbreak(str):
    if str >= '2020-01-17' and str < '2020-06-31':
        return 'First'
    elif str >= '2020-07-01' and str < '2020-09-32':
        return 'Second'
    elif str >= '2020-10-01' and str < '2021-01-32':
        return 'Third'
    else:
        return 'Fourth'

# %%
merge['outbreak'] = merge['date'].apply(outbreak)
merge.head()
# Out:
#          date      open      high       low     close  adjClose    Volume  \
# 0  2020-01-17  1.023347  0.960660  1.016661  0.942442  0.597908  0.119182
# 1  2020-01-17  0.601565  0.586984  0.632275  0.624465  0.625632 -1.043669
# 2  2020-01-17  1.032462  1.034940  1.105736  1.048338  1.013701 -0.475912
# 3  2020-01-17 -0.315506 -0.346484 -0.279123 -0.308886 -0.121903 -0.500143
# 4  2020-01-17 -0.331298 -0.368726 -0.302040 -0.320879 -0.320879 -0.974003
#
#         maker       diff  deathIncrease  hospitalizedIncrease  \
# 0         bmw  -7.443496            NaN                   NaN
# 1      toyota   0.360000            NaN                   NaN
# 2  Volkswagen -10.366912            NaN                   NaN
# 3          gm  -0.399052            NaN                   NaN
# 4       honda   0.020001            NaN                   NaN
#
#    positiveIncrease  totalTestResultsIncrease outbreak
# 0               NaN                       NaN    First
# ...

# %% [markdown]
# With all data merged together and cleaned proporly, we should visualize the data to find any potential relationships. Thanks to our previous EDA analysis, we understand that the distribution of adjusted close price share similar trends accross automotive companies, thus we no longer to differentiate between car brands and explore the generalized correlation between daily increase of Covid-19 and stock prices of automotive companies. To visualize the data, we first used regplot to make 4 subplots, each representing a different outbreak period, to see if there is any potential correlations.

# %%
fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(ncols = 2, nrows = 2, sharey = True, figsize=(20,30))
sns.set(font_scale=1, style="white")

sns.regplot(data = merge[merge['outbreak']=='First'], ax=ax1, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['outbreak']=='Second'], ax=ax2, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['outbreak']=='Third'], ax=ax3, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})
sns.regplot(data = merge[merge['outbreak']=='Fourth'], ax=ax4, x = 'positiveIncrease', y = 'adjClose',line_kws={"color": "red"})

plt.suptitle('Correlation between Daily Increase with Stock of Each Outbreak Period', fontsize=20)
fig.subplots_adjust(top=0.95)
ax1.title.set_text('First Outbreak')
ax2.title.set_text('Second Outbreak')
ax3.title.set_text('Third Outbreak')
ax4.title.set_text('Fourth Outbreak')

# %% [markdown]
# Although there seems to have a correlation between daily increase of Covid-19 and adjusted close stock price of car companies during the third outbreak period, the rest of plots show little to no direct correlation, especially in the fourth period where dotts are rather sparse and seem to have no obvious distribution. To further explore any potential correlations, we use a scatter matrix, which contains daily increase of Covid-19 cases as well as adjusted close prices of stocks of automotive companies.

# %%
sns.pairplot(merge, hue = 'outbreak', vars = ["adjClose", "positiveIncrease"], palette = 'Paired', height = 4)

# %% [markdown]
# Although the means for adjusted close price are quite similar for the first 3 outbreaks, that of the 4th outbreak differs drastically. In addition, daily increases also differ quite differently in differet outbreak period. And the distribution for adjusted close price and daily increase of Covid-19 do not align. Thus, there doesn't appear to be a strong correlation between stock price of automotive companies with daily increase of Covid-19. Given the scatter matrix, it seems that daily increase of Covid-19 cases does not affect the stock price of automotive companies.
#
# In order to further analyze whther or not a significant relationship exists between daily increase of Covid-19 with stock prices of car companies, we'll perform linear regression on the adjusted close price and daily increase of Covid-19 for each outbreak period.

# %%
for i in ['First', 'Second', 'Third', 'Fourth']:
    print('Outbreak Period:', i)
    reg_df = merge[['adjClose', 'positiveIncrease', 'outbreak']]
    reg_df = reg_df[ reg_df['outbreak']==i ]
    outcome, predictors = patsy.dmatrices("positiveIncrease ~ adjClose", reg_df)

    mod_log = sm.OLS(outcome, predictors)

    fit_res = mod_log.fit()

    print(fit_res.summary())
    print("\n")
# Out:
# Outbreak Period: First
#                             OLS Regression Results
# ...
# Dep. Variable:       positiveIncrease   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     42.44
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):           1.45e-10
# Time:                        11:25:26   Log-Likelihood:                 211.82
# No. Observations:                 661   AIC:                            -419.6
# Df Residuals:                     659   BIC:                            -410.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8735      0.011    -77.410      0.000      -0.896      -0.851
# ...

# %% [markdown]
# Based off the p-value returned by linear regression analysis for each outbreak period, we can see that the p-value for the first, second and third outbreak period is relatively small, thus we can consider the increase of daily cases of Covid-19 to be a statistically significant predictor of stock prices of automotive companies. However, in the fourth outbreak period, the p-value is rather large and fails to indicate the existence of correlation.
#
# Overall, we can see that even though the correlation between the increase of daily cases of Covid-19 and stock prices of automotive companies may not be consistent throughout the time scope of our study, the increase of daily cases of Covid-19 can nonetheless be seen as a statistically significant predictor of stock prices of automotive companies during the period Jan 2020-Jan 2021. However, the p-value in regression analysis that represents the correlation in the fourth outbreak period indicate that seeing the result as it is is quite likely(30.4%) due a random chance alone, which does not support the hypothesis that daily increase of Covid-19 cases has a correlation with stock price of automotive companies. Nonetheless, as for outbreak period 1, 2 and 3, the regression analysis combined with scatter matrix does indicate a strong correlation between daily increase of Covid-19 cases and stock price of automotive companies during the period from Jan 2020 to Jan 2021.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Given that our research question relates to a somewhat sensitive topic: the ongoing penemic of Covid-19, we need to be extra cautious about the dataset we choose to use to make sure that personally identifiable information is as limited as possible while making sure that the lack of PII would not impair the progress of our research. In addition, we make sure that all datasets are collected with informed consent, meaning that all observations are aware that they’re being sampled.
#
# <br>
# Apart from data related to Covid-19, we also need to be cautious about the data regarding stock price per share of automotive companies, as a single source of information tends to be biased considering such resources may be influenced due to sponsorship from car brands. Thus, it is imperative that we collect data from multiple sources to minimize potential bias that could exist in our data.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# Conclusion:
# After performing our analysis, we could only partially support our original hypothesis that there is a relationship between the increase of coronavirus disease cases and the decrease of stock price per share of automotive companies. From the EDA conclusion, we know that the severity of the epidemic can be divided into four parts. We concluded that at the beginning of the outbreak, from January 2020 to January 2021, the severity of COVID-19 had a strong positive correlation with stock price per share of automotive companies. But at the third breakpoint, the severity of COVID-19 has a strong negative correlation with stock price per share of automotive companies. This verifies our conjecture that the impact of the epidemic on people's lives is getting smaller and smaller as time goes on, so auto stock prices slowly recovered levels before the outbreak began. After the fourth inflection point we can derive from our scatter matrix that daily increase of Covid-19 cases does not affect the stock price of automotive companies. And by using linear regression, we can see that we failed to indicate the existence of correlation in the fourth outbreak period. In a word, we indicated a strong correlation between daily increase of Covid-19 cases and stock price of automotive companies during the period from Jan 2020 to Jan 2021.

# %% [markdown]
# Discussion:
# In the hypothesis, we assume that there is a relationship between the increase of coronavirus disease cases and the decrease of stock price per share of automotive companies. From the EDA conclusion, we used plot and correlation to find out if there is a strong relationship between these two. First, all of our correlation graphs follow a similar trend, that start from a low position and become higher in the "adjusted close stock price" when the "positive increased cases" is higher. However, based on different time ranges, we see that there is a strong positive relationship between the coronavirus disease cases and the stock price during the first and second major outbreak and a negative relationship during the third major outbreak, which shows that there should exist some other hidden elements that affect the stock price. For example, the expected growth in the earnings base(Annual financial statements), the function of inflation and the economic strength of market and peers could all be the factors that affect the stock price. Recently, the conflict between Russia and Ukraine caused stock prices to go down a lot, which is also a factor that will affect the stock prices, and this incident is unpredicted. These hidden factors could be the reasons that cause a difference between our expected conclusion and actual conclusion.
# We are limited in this project by only looking at the data of Covid-19 New Cases. One of the important factors is that the policy towards the pandemic changes often. At the very beginning of the pandemic, around Mar 2020, all the cities were locked down and people were restricted to go out to public places, and this situation lasted for a long time until the vaccine came out. That's why we have a negative relationship between Covid-19 New Cases and Automotive Stock Price. However, after several months lockdown, the society began to go back on the right track with the help of vaccination. If our data analyze also includes the dataset vaccination rate(1st dose, 2nd dose and booster), we can get a more comprehensive analysis.

# %% [markdown]
# #### Limitations

# %% [markdown]
# One potential limitation is that our selection of dataset regarding car stocks may slightly influence our research outcome. Due to the large number of brands of motor vehicles, analyzing all of them would be impossible for us. Thus, we decided to analyze the stocks of seven datasets for stock prices for seven brands that are representative to the whole market of car stocks. Though each of  them represents one price level of the motor vehicles, they still can not truly represent the whole situation of the car stock prices, which may slightly alter our EDA conclusion and how much we can support our original hypothesis.
#
# Another potential limitation is that in the fourth outbreak period of Covid-19, the p-value we measured is rather large and fails to indicate the existence of correlation. However, we still can conclude that during the first three periods, there exists a strong correlation between the daily increase of Covid-19 and stock price of automotive companies during the period from Jan 2020 to Jan 2021

# %% [markdown]
# # Team Contributions

# %% [markdown]
# Harry Lei - Data Cleaning, Data Gathering, EDA Analysis, Ethics & Privacy, Research Question, Further Analysis

# %% [markdown]
# Chenyu Zhang - Data Collecting, Hypothesis, Data Cleaning, Reseach Question, Conclusion & Discussion, Final Video Preparation, Final Video Presentation

# %% [markdown]
# Zhengxi Zhang - Data Collecting, Hypothesis, EDA Analysis, Research Question, Data Gathering, Conclusion & Discussion, Final Veideo Preparation, Final Video.

# %% [markdown]
# Hongchang Jiang - Overview, Research Question, Hypothesis, Data Gathering, Data Analysis & Results(EDA), Further Analysis

# %% [markdown]
# Mengyuan Zhang - Research question, Hypothesis, Data Gathering, Limitation, Final Video Preparation, Final Video
